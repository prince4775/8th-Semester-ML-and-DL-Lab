# %% [markdown]
# # Lab 2.3: Introduction to Matplotlib
#
#
# **University of Engineering and Technology Peshawar, Nowshera Campus**
#
# **Course:** Machine Learning Lab
#
# **Student Name:** Muhammad Ayub
# **Registration Number:** 22jzele0470
#
# **Date:** May 14, 2026
#
# ---
#
# ## Table of Contents
#
# 1. [Import Matplotlib](#1-import-matplotlib)
# 2. [Basic Line Plot](#2-basic-line-plot)
# 3. [Titles, Labels and Grid](#3-titles-labels-and-grid)
# 4. [Styling: Color, Marker, Line](#4-styling-color-marker-line)
# 5. [Subplots](#5-subplots)
# 6. [Mini Exercises](#6-mini-exercises)
#
# ---
#
# **GitHub Repository:**
# https://github.com/prince4775/8th-Semester-ML-and-DL-Lab

# %% [markdown]
# ## 1. Import Matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Basic Line Plot

# %%
# Simple line plot
x = [1, 2, 3, 4, 5]
y = [10, 12, 8, 15, 11]

plt.plot(x, y)
plt.show()

# %% [markdown]
# ## 3. Titles, Labels and Grid

# %%
x = [1, 2, 3, 4, 5]
y = [10, 12, 8, 15, 11]

plt.plot(x, y)

plt.title("Student Marks Over Days")
plt.xlabel("Days")
plt.ylabel("Marks")

plt.grid(True)

plt.show()

# %% [markdown]
# ## 4. Styling: Color, Marker, Line

# %%
x = [1, 2, 3, 4, 5]
y = [10, 12, 8, 15, 11]

plt.plot(x, y, color='red', marker='o', linestyle='--', linewidth=2, markersize=8)

plt.title("Styled Line Plot")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.grid(True)
plt.show()

# %% [markdown]
# ## 5. Subplots

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

# Plot 1
axes[0, 0].plot([1,2,3,4], [10,20,25,30], 'b-o')
axes[0, 0].set_title("Line Plot")

# Plot 2
axes[0, 1].bar(['A','B','C'], [5,7,3], color='orange')
axes[0, 1].set_title("Bar Plot")

# Plot 3
axes[1, 0].scatter([1,2,3,4,5], [2,5,3,8,1], color='green')
axes[1, 0].set_title("Scatter Plot")

# Plot 4
axes[1, 1].hist([1,2,2,3,3,3,4,5,5], bins=5, color='purple')
axes[1, 1].set_title("Histogram")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Mini Exercises

# %% [markdown]
# 1. Create a line plot showing temperature for 7 days.
# 2. Make a bar chart of 5 favorite fruits.
# 3. Create a scatter plot of student height vs weight.
# 4. Make a pie chart of daily activities.
# 5. Create a histogram of marks.
# 6. Combine line and bar plots using subplots.
#
# Add titles, labels, grid, colors, and markers!

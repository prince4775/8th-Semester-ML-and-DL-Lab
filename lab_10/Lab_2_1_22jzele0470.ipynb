# %% [markdown]
# # Lab 2.1: Introduction to NumPy
#
# **University of Engineering and Technology Peshawar, Nowshera Campus**
#
# **Course:** Machine Learning Lab
#
# **Student Name:** Muhammad Ayub
# **Registration Number:** 22jzele0470
#
# **Date:** May 14, 2026
#
# ---
#
# ## Table of Contents
#
# 1. [Introduction to NumPy](#1-introduction-to-numpy)
# 2. [Installation](#2-installation)
# 3. [Import NumPy](#3-import-numpy)
# 4. [Array Creation](#4-array-creation)
# 5. [Indexing and Slicing](#5-indexing-and-slicing)
# 6. [Mathematical Operations](#6-mathematical-operations)
# 7. [Statistical Functions](#7-statistical-functions)
#
# ---
#
# **GitHub Repository:**
# https://github.com/prince4775/8th-Semester-ML-and-DL-Lab

# %% [markdown]
# ## 1. Introduction to NumPy

# %% [markdown]
# NumPy is a powerful Python library for numerical computing, providing support for large, multi-dimensional arrays and matrices, along with a collection of high-level mathematical functions to operate on these arrays efficiently. It serves as the foundation for many scientific and mathematical Python libraries due to its speed and versatility. NumPy offers capabilities for array manipulation, mathematical operations, linear algebra, random number generation, and more, making it an essential tool for data manipulation and analysis in fields such as machine learning, data science, and engineering. With its efficient implementation in C, NumPy facilitates fast computations and enables seamless integration with other Python libraries and tools. Its simplicity and performance make it a cornerstone of the Python scientific computing ecosystem.

# %% [markdown]
# ## 2. Installation

# %% [markdown]
# We can easily install this library using the terminal. Follow the steps given below to install Numpy:<br>
# Step 1: Go to the Windows PowerShell.<br>
# Step 2: We can install Numpy with the help of pip easily. Head over to the directory where you want to install the numpy and fire the below command:<br>
# __pip install numpy__<br>
# __OR__<br>
# __conda install numpy__<br>
# This is very simple to install.

# %% [markdown]
# ## 3. Import NumPy

# %%
import numpy as np

# %% [markdown]
# ## 4. Array Creation

# %% [markdown]
# ### 4.1 Creating an array from list

# %%
mylist=[1,3,5,6]

# %%
type(mylist)

# %%
np.array(mylist)

# %%
type(mylist)

# %%
arr=np.array(mylist)

# %%
arr

# %% [markdown]
# ### 4.2 Creating matrix

# %%
mylist=[[1,3,5],[4,5,6],[1,4,76],[1,3,5]]

# %%
np.array(mylist)

# %%
mymatrix = np.array(mylist)

# %%
mymatrix.shape

# %% [markdown]
# ### 4.3 Creating the numpy array by using range function

# %%
np.arange(0,5)

# %%
np.arange(0,10,2)

# %% [markdown]
# ### 4.4 Creating the numpy array of only Zeros

# %%
np.zeros(5)

# %% [markdown]
# ### 4.5 Creating the matrix of only Zeros

# %%
np.zeros((4,10))

# %% [markdown]
# ### 4.6 Creating the matrix of only 1

# %%
np.ones((5,5))

# %%
np.ones((5,5)) +5

# %%
np.ones(4)*100

# %%
np.ones(4)/100

# %% [markdown]
# ### 4.7 Creating of array by using linspace function

# %%
np.linspace(0,10,5)

# %%
len(np.linspace(0,10,20))

# %% [markdown]
# ### 4.8 Eye function

# %%
np.eye(3)

# %% [markdown]
# ### 4.9 Random numbers

# %%
np.random.rand(5)

# %%
np.random.rand(3,5)

# %%
np.random.randint(1,100,5)

# %% [markdown]
# ## 5. Indexing and Slicing

# %%
arr=np.arange(11)
arr

# %%
arr[8]

# %%
arr[2]

# %%
arr[1:5]

# %%
arr[:]

# %%
arr[5:]

# %%
arr[:5]

# %%
arr[4:7]

# %%
arr[0:6]

# %% [markdown]
# ## 6. Mathematical Operations

# %%
arr+100

# %%
arr / 2

# %%
arr**2

# %% [markdown]
# ## 7. Statistical Functions

# %%
arr = np.array([4, 9, 2, 7, 5])
print("Array:", arr)
print("Mean:", arr.mean())
print("Max:", arr.max())
print("Min:", arr.min())
print("Argmax:", arr.argmax())
print("Argmin:", arr.argmin())
print("Standard Deviation:", arr.std())
print("Variance:", arr.var())
print("Median:", np.median(arr))
print("Sum:", arr.sum())
print("Cumulative Sum:", arr.cumsum())
print("Sorted Array:", np.sort(arr))

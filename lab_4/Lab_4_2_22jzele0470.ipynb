# %% [markdown]
# # Lab 4.2: AEP Correlation Analysis
#
# **Prepared by:** Muhammad Ayub
# **Registration No:** 22jzele0470
# **Date:** Saturday, May 23, 2026
#
# ---
#
# ## Table of Contents
#
# 1. [Imports and Data Loading](#1-imports-and-data-loading)
# 2. [Pearson Correlation](#2-pearson-correlation)
# 3. [Kendall Correlation](#3-kendall-correlation)
# 4. [Spearman Correlation](#4-spearman-correlation)
# 5. [Missing Values Check](#5-missing-values-check)
#
# ---
#
# **GitHub Repository:**
# https://github.com/prince4775/8th-Semester-ML-and-DL-Lab

# %% [markdown]
# ## 1. Imports and Data Loading

# %%
import pandas as pd
import numpy as np
#from dataprep.datasets import load_dataset   # Used to import / load dataset
#from dataprep.eda import create_report   # Used to load Report formate

# %%
df=pd.read_csv(r'C:\Users\M Ayub\Downloads\ML_LAB\5_features_extracted.csv', index_col=['Datetime'], parse_dates=['Datetime'])
df.head()

# %% [markdown]
# ## 2. Pearson Correlation

# %%
print('pearson\n\n',df.corrwith(df["aep"],method="pearson"))

# %% [markdown]
# ## 3. Kendall Correlation

# %%
print('kendall\n\n',df.corrwith(df["aep"],method="kendall"))

# %% [markdown]
# ## 4. Spearman Correlation

# %%
print('spearman\n\n',df.corrwith(df["aep"],method="spearman"))

# %% [markdown]
# ## 5. Missing Values Check

# %%
df.isnull().sum()
